# %% [markdown]
# **TALLER 2B : MATRIZ INVERSA - DESCOMOPOSICIÓN LU**
#
# **Nombre:**
#
# **Fecha:**
#
# **repositorio:**

# %% [markdown]
# para encontrar la matriz inversa de las siguientes matrices:

# %%
A1= [
    [1, 3, 4],
    [2, 1, 3],
    [4, 2, 1]
]

# %%
A2= [
    [1, 3, 4],
    [0, 1, 4],
    [5, 6, 0]
]

# %%
A3= [
    [4, 2, 1],
    [2, 1, 3],
    [1, 3, 4]
]

# %%
A4= [
    [2, 4, 6, 1],
    [4, 7, 5, -6],
    [2, 5, 18, 10],
    [6, 12, 38, 16]
]

# %% [markdown]
# Calcule la descomposición LU para estas matrices y encuentre la solución para estos vectores de valores independientes $b$

# %%
b1= [
 [1],
 [2],
 [4]
]

# %%
b2= [
 [3],
 [-5],
 [2]
]

# %%
b3= [
 [7],
 [8],
 [11]
]

# %%
b1= [
 [1],
 [2],
 [4],
 [5]
]

# %%
b2= [
 [3],
 [-5],
 [2],
 [6]
]

# %%
b3= [
 [7],
 [8],
 [-1],
 [0]
]
